# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/user1-all-h5/_hand.h5
# /kaggle/input/user1-all-h5/_hips.h5
# /kaggle/input/user1-all-h5/_torso.h5
# /kaggle/input/user1-all-h5/_bag.h5

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import tensorflow as tf
from sklearn import metrics
import h5py
import matplotlib.pyplot as plt
from tensorflow.keras import regularizers
from tensorflow.keras.layers import Input, Conv2D, Dense, Flatten, Dropout, SimpleRNN, GRU, LSTM, GlobalMaxPooling1D,GlobalMaxPooling2D,MaxPooling2D,BatchNormalization
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.losses import binary_crossentropy, categorical_crossentropy
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import itertools
from keras.utils.vis_utils import plot_model

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import tensorflow as tf
from sklearn import metrics
import h5py
import matplotlib.pyplot as plt
from tensorflow.keras import regularizers
from tensorflow.keras.layers import Input,Conv1D, Conv2D, Dense, Flatten, Dropout, SimpleRNN, GRU, LSTM, GlobalMaxPooling1D,GlobalMaxPooling2D,MaxPooling2D,BatchNormalization
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.losses import binary_crossentropy, categorical_crossentropy
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import itertools
from keras.utils.vis_utils import plot_model
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers

# %%
class models():
    def __init__(self, path):
        self.path = path
        
        
    def read_h5(self):
        f = h5py.File(path, 'r')
        X = f.get('inputs')
        y = f.get('labels') 
        
        X = np.array(X)
        y = np.array(y)
        self.x_train, self.x_test, self.y_train, self.y_test = train_test_split(X, y, test_size=0.2, random_state = 1)
        print(self.x_train.shape,self.y_train.shape)
    def draw(self):
        f1 = plt.figure(1)
        plt.title('Loss')
        plt.plot(self.r.history['loss'], label = 'loss')
        plt.plot(self.r.history['val_loss'], label = 'val_loss')
        plt.legend()
        f1.show()
        
        f2 = plt.figure(2)
        plt.plot(self.r.history['accuracy'], label = 'accuracy')
        plt.plot(self.r.history['val_accuracy'], label = 'val_accuracy')
        plt.legend()
        f2.show()    
#     def cnn_model(self):
#         K = len(set(self.y_train))
# #         print(K)
        
#         print(self.x_train.shape,self.y_train.shape)
# #         Input_shape should be a 4dim vectors as stated in the keras doc:
#         self.x_train = np.expand_dims(self.x_train, -1)
#         self.x_test = np.expand_dims(self.x_test,-1)
#         print(self.x_train.shape,self.y_train.shape)
        
#         i = Input(shape=self.x_train[0].shape)
#         print(self.x_train[0].shape)
#         x = Conv2D(16, (3,3), strides = 2, activation = 'relu',padding='same',kernel_regularizer=regularizers.l2(0.0005))(i)
#         x = BatchNormalization()(x)
#         x = Dropout(0.2)(x)
#         x = Flatten()(x)    
#         x = Dropout(0.2)(x)
#         x = Dense(128,activation = 'relu')(x)
#         x = BatchNormalization()(x)
#         x = Dropout(0.2)(x)
#         x = Dense(K, activation = 'softmax')(x)       
#         self.model = Model(i,x)
#         self.model.compile(optimizer = Adam(learning_rate=0.0005),
#               loss = 'sparse_categorical_crossentropy',
#               metrics = ['accuracy'])
        
#         self.r = self.model.fit(self.x_train, self.y_train, validation_data = (self.x_test, self.y_test), epochs = 200, batch_size = 128 )
#         print(self.model.summary())
#         return self.r
    
    def cnn_model_2(self):
        K = len(set(self.y_train))
#         print(K)
        
        print(self.x_train.shape,self.y_train.shape)
#         Input_shape should be a 4dim vectors as stated in the keras doc:
#         self.x_train = np.expand_dims(self.x_train, -1)
#         self.x_test = np.expand_dims(self.x_test,-1)
        print(self.x_train.shape,self.y_train.shape)
        
        i = Input(shape=self.x_train[0].shape)
        print(self.x_train[0].shape)
        x = Conv1D(32, 5, strides = 1, activation = 'relu',padding='same',kernel_regularizer=regularizers.l2(0.0005))(i)
        #x = BatchNormalization()(x)
        x = MaxPooling2D(pool_size=(1,2), strides=(1,2))
        #x = Dropout(0.2)(x)
        #x = Flatten()(x)    
        #x = Dropout(0.2)(x)
        x = Conv1D(64, 3, strides = 1, activation = 'relu',padding='same',kernel_regularizer=regularizers.l2(0.0005))(i)
        #x = BatchNormalization()(x)
        x = MaxPooling2D(pool_size=(1,2), strides=(1,2))
        #x = Dropout(0.2)(x)
        #x = Flatten()(x)  
        #x = Dropout(0.2)(x)
        x = Conv1D(128, 3, strides = 1, activation = 'relu',padding='same',kernel_regularizer=regularizers.l2(0.0005))(i)
#         x=layers.Reshape((500, 23), input_shape=x.shape)
        x = layers.LSTM(64, return_sequences=True)(x)
        #x = Bidirectional(LSTM(64))(x)
        x = Flatten()(x)
        x = Dense(8, activation = 'softmax')(x)
        
        self.model = Model(i,x)
        self.model.compile(optimizer = Adam(learning_rate=0.0005),
              loss = 'sparse_categorical_crossentropy',
              metrics = ['accuracy'])
        
        self.r = self.model.fit(self.x_train, self.y_train, validation_data = (self.x_test, self.y_test), epochs = 200, batch_size = 128 )
        print(self.model.summary())
        return self.r
    
        
    def con_matrix(self):
        K = len(set(self.y_train))
        self.y_pred = self.model.predict(self.x_test).argmax(axis=1)
        cm = confusion_matrix(self.y_test,self.y_pred)
        self.plot_confusion_matrix(cm,list(range(K)))
    
    def plot_confusion_matrix(self, cm, classes, normalize = False, title='Confusion matrix', cmap=plt.cm.Blues):
        if normalize:
            cm = cm.astype('float') / cm.sum(axis=1)[:,np.newaxis]
            print("Normalized confusion matrix")
        else:
            print("Confusion matrix, without normalization")
        print(cm)
        f3 = plt.figure(3)
        plt.imshow(cm, interpolation='nearest', cmap=cmap)
        plt.title(title)
        plt.colorbar()
        tick_marks = np.arange(len(classes))
        plt.xticks(tick_marks, classes, rotation=45)
        plt.yticks(tick_marks, classes)
        
        fmt = '.2f' if normalize else 'd' 
        thresh = cm.max()/2.
        for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
            plt.text(j, i, format(cm[i, j], fmt),
                     horizontalalignment = "center",
                     color = "white" if cm[i, j] > thresh else "black")
            plt.tight_layout()
            plt.ylabel('True label')
            plt.xlabel('predicted label')
            f3.show()

# %%
model_name = "cnn" 
path='/kaggle/input/user1-all-h5/_torso.h5'
motion = models(path)
motion.read_h5()
model=motion.cnn_model_2()
motion.draw()
motion.con_matrix()
# Out:
# (9716, 500, 22) (9716,)
# (9716, 500, 22) (9716,)
# (9716, 500, 22) (9716,)
# (500, 22)
# 2022-11-08 12:40:32.237638: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 12:40:32.238615: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 12:40:32.386609: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 12:40:32.387417: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 12:40:32.388147: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 12:40:32.388864: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 12:40:32.390768: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-08 12:40:32.646143: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 12:40:32.647039: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 12:40:32.647804: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 12:40:32.648535: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 12:40:32.649231: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 12:40:32.650014: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 12:40:36.448505: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 12:40:36.449703: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 12:40:36.450722: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 12:40:36.451735: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 12:40:36.452887: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 12:40:36.453956: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13789 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 2022-11-08 12:40:36.457995: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 12:40:36.458921: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13789 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# 2022-11-08 12:40:38.587576: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/200
# 2022-11-08 12:40:41.965195: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 76/76 [==============================] - 15s 42ms/step - loss: 1.8933 - accuracy: 0.3319 - val_loss: 1.4387 - val_accuracy: 0.4514
# Epoch 2/200
# 76/76 [==============================] - 2s 32ms/step - loss: 1.4415 - accuracy: 0.4343 - val_loss: 1.4131 - val_accuracy: 0.4053
# Epoch 3/200
# 76/76 [==============================] - 3s 35ms/step - loss: 1.3226 - accuracy: 0.4647 - val_loss: 1.2157 - val_accuracy: 0.5436
# Epoch 4/200
# 76/76 [==============================] - 2s 32ms/step - loss: 1.2611 - accuracy: 0.5031 - val_loss: 1.1403 - val_accuracy: 0.5761
# Epoch 5/200
# 76/76 [==============================] - 2s 32ms/step - loss: 1.1267 - accuracy: 0.5739 - val_loss: 0.9388 - val_accuracy: 0.6593
# Epoch 6/200
# 76/76 [==============================] - 3s 39ms/step - loss: 1.0502 - accuracy: 0.6136 - val_loss: 0.9774 - val_accuracy: 0.6539
# Epoch 7/200
# 76/76 [==============================] - 3s 35ms/step - loss: 0.8875 - accuracy: 0.6701 - val_loss: 0.7931 - val_accuracy: 0.7230
# Epoch 8/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.8875 - accuracy: 0.6764 - val_loss: 0.7947 - val_accuracy: 0.7420
# Epoch 9/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.8132 - accuracy: 0.7032 - val_loss: 0.9127 - val_accuracy: 0.6247
# Epoch 10/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.8101 - accuracy: 0.7014 - val_loss: 0.8011 - val_accuracy: 0.7082
# Epoch 11/200
# 76/76 [==============================] - 3s 35ms/step - loss: 0.8165 - accuracy: 0.6996 - val_loss: 0.7781 - val_accuracy: 0.7362
# Epoch 12/200
# 76/76 [==============================] - 3s 35ms/step - loss: 0.7535 - accuracy: 0.7257 - val_loss: 0.7768 - val_accuracy: 0.7173
# Epoch 13/200
# 76/76 [==============================] - 2s 33ms/step - loss: 0.7512 - accuracy: 0.7346 - val_loss: 0.8079 - val_accuracy: 0.7041
# Epoch 14/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.6882 - accuracy: 0.7594 - val_loss: 0.6694 - val_accuracy: 0.7901
# Epoch 15/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.6323 - accuracy: 0.7832 - val_loss: 0.6383 - val_accuracy: 0.7794
# Epoch 16/200
# 76/76 [==============================] - 3s 35ms/step - loss: 0.6436 - accuracy: 0.7726 - val_loss: 0.7009 - val_accuracy: 0.7683
# Epoch 17/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.7433 - accuracy: 0.7437 - val_loss: 0.7295 - val_accuracy: 0.7691
# Epoch 18/200
# 76/76 [==============================] - 3s 39ms/step - loss: 0.6466 - accuracy: 0.7803 - val_loss: 0.6708 - val_accuracy: 0.7724
# Epoch 19/200
# 76/76 [==============================] - 2s 33ms/step - loss: 0.6401 - accuracy: 0.7767 - val_loss: 0.7003 - val_accuracy: 0.7383
# Epoch 20/200
# 76/76 [==============================] - 3s 35ms/step - loss: 0.6624 - accuracy: 0.7690 - val_loss: 0.7115 - val_accuracy: 0.7671
# Epoch 21/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.6799 - accuracy: 0.7698 - val_loss: 0.6238 - val_accuracy: 0.7807
# Epoch 22/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.5763 - accuracy: 0.8102 - val_loss: 0.5906 - val_accuracy: 0.8181
# Epoch 23/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.6651 - accuracy: 0.7695 - val_loss: 0.6251 - val_accuracy: 0.7901
# Epoch 24/200
# 76/76 [==============================] - 3s 36ms/step - loss: 0.6204 - accuracy: 0.7893 - val_loss: 0.7610 - val_accuracy: 0.7539
# Epoch 25/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.6363 - accuracy: 0.7755 - val_loss: 0.6757 - val_accuracy: 0.7720
# Epoch 26/200
# 76/76 [==============================] - 2s 33ms/step - loss: 0.6271 - accuracy: 0.7774 - val_loss: 0.6784 - val_accuracy: 0.7815
# Epoch 27/200
# 76/76 [==============================] - 2s 33ms/step - loss: 0.6172 - accuracy: 0.7889 - val_loss: 0.6362 - val_accuracy: 0.7897
# Epoch 28/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.6129 - accuracy: 0.7871 - val_loss: 0.7121 - val_accuracy: 0.7675
# Epoch 29/200
# 76/76 [==============================] - 3s 35ms/step - loss: 0.6165 - accuracy: 0.7901 - val_loss: 0.7443 - val_accuracy: 0.7576
# Epoch 30/200
# 76/76 [==============================] - 3s 36ms/step - loss: 0.5908 - accuracy: 0.7994 - val_loss: 0.6350 - val_accuracy: 0.7741
# Epoch 31/200
# 76/76 [==============================] - 3s 36ms/step - loss: 0.8652 - accuracy: 0.7049 - val_loss: 0.8917 - val_accuracy: 0.6593
# Epoch 32/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.8909 - accuracy: 0.6890 - val_loss: 1.0579 - val_accuracy: 0.6432
# Epoch 33/200
# 76/76 [==============================] - 3s 35ms/step - loss: 0.8206 - accuracy: 0.7333 - val_loss: 0.7418 - val_accuracy: 0.7733
# Epoch 34/200
# 76/76 [==============================] - 2s 33ms/step - loss: 0.6914 - accuracy: 0.7796 - val_loss: 0.6451 - val_accuracy: 0.8016
# Epoch 35/200
# 76/76 [==============================] - 2s 33ms/step - loss: 0.6287 - accuracy: 0.7879 - val_loss: 0.6183 - val_accuracy: 0.8033
# Epoch 36/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.6449 - accuracy: 0.7830 - val_loss: 0.6648 - val_accuracy: 0.7720
# Epoch 37/200
# 76/76 [==============================] - 3s 35ms/step - loss: 0.6147 - accuracy: 0.7932 - val_loss: 0.6815 - val_accuracy: 0.7626
# Epoch 38/200
# 76/76 [==============================] - 2s 33ms/step - loss: 0.6933 - accuracy: 0.7571 - val_loss: 0.8983 - val_accuracy: 0.7078
# Epoch 39/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.7085 - accuracy: 0.7622 - val_loss: 0.6219 - val_accuracy: 0.8086
# Epoch 40/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.5830 - accuracy: 0.8021 - val_loss: 1.0757 - val_accuracy: 0.6798
# Epoch 41/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.7205 - accuracy: 0.7569 - val_loss: 0.7527 - val_accuracy: 0.7741
# Epoch 42/200
# 76/76 [==============================] - 3s 35ms/step - loss: 0.6195 - accuracy: 0.7934 - val_loss: 0.8633 - val_accuracy: 0.7136
# Epoch 43/200
# 76/76 [==============================] - 3s 39ms/step - loss: 0.6176 - accuracy: 0.7932 - val_loss: 0.5427 - val_accuracy: 0.8276
# Epoch 44/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.5408 - accuracy: 0.8244 - val_loss: 0.5431 - val_accuracy: 0.8247
# Epoch 45/200
# 76/76 [==============================] - 2s 33ms/step - loss: 0.5192 - accuracy: 0.8269 - val_loss: 0.5146 - val_accuracy: 0.8412
# Epoch 46/200
# 76/76 [==============================] - 3s 35ms/step - loss: 0.5184 - accuracy: 0.8321 - val_loss: 0.5781 - val_accuracy: 0.8354
# Epoch 47/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.5035 - accuracy: 0.8392 - val_loss: 0.5003 - val_accuracy: 0.8519
# Epoch 48/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.5126 - accuracy: 0.8289 - val_loss: 0.7237 - val_accuracy: 0.7889
# Epoch 49/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.5573 - accuracy: 0.8202 - val_loss: 0.7040 - val_accuracy: 0.7683
# Epoch 50/200
# 76/76 [==============================] - 3s 36ms/step - loss: 0.5634 - accuracy: 0.8129 - val_loss: 0.5969 - val_accuracy: 0.7922
# Epoch 51/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.5484 - accuracy: 0.8245 - val_loss: 0.5613 - val_accuracy: 0.8243
# Epoch 52/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.4964 - accuracy: 0.8373 - val_loss: 0.5247 - val_accuracy: 0.8362
# Epoch 53/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.5199 - accuracy: 0.8326 - val_loss: 0.5391 - val_accuracy: 0.8453
# Epoch 54/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.5408 - accuracy: 0.8217 - val_loss: 0.6060 - val_accuracy: 0.8033
# Epoch 55/200
# 76/76 [==============================] - 3s 42ms/step - loss: 0.6288 - accuracy: 0.7836 - val_loss: 0.5940 - val_accuracy: 0.8300
# Epoch 56/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.5963 - accuracy: 0.8037 - val_loss: 0.5907 - val_accuracy: 0.8152
# Epoch 57/200
# 76/76 [==============================] - 2s 33ms/step - loss: 0.5319 - accuracy: 0.8265 - val_loss: 0.6089 - val_accuracy: 0.8247
# Epoch 58/200
# 76/76 [==============================] - 2s 33ms/step - loss: 0.5038 - accuracy: 0.8351 - val_loss: 0.5047 - val_accuracy: 0.8453
# Epoch 59/200
# 76/76 [==============================] - 3s 36ms/step - loss: 0.4705 - accuracy: 0.8463 - val_loss: 0.5905 - val_accuracy: 0.8144
# Epoch 60/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.5981 - accuracy: 0.8052 - val_loss: 0.5138 - val_accuracy: 0.8354
# Epoch 61/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.4976 - accuracy: 0.8370 - val_loss: 0.5512 - val_accuracy: 0.8317
# Epoch 62/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.4959 - accuracy: 0.8380 - val_loss: 0.5162 - val_accuracy: 0.8362
# Epoch 63/200
# 76/76 [==============================] - 3s 35ms/step - loss: 0.4464 - accuracy: 0.8580 - val_loss: 0.5081 - val_accuracy: 0.8494
# Epoch 64/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.4587 - accuracy: 0.8537 - val_loss: 0.6315 - val_accuracy: 0.8078
# Epoch 65/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.5009 - accuracy: 0.8362 - val_loss: 0.5847 - val_accuracy: 0.8230
# Epoch 66/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.4829 - accuracy: 0.8409 - val_loss: 0.5677 - val_accuracy: 0.8305
# Epoch 67/200
# 76/76 [==============================] - 3s 38ms/step - loss: 0.4808 - accuracy: 0.8456 - val_loss: 0.6587 - val_accuracy: 0.7992
# Epoch 68/200
# 76/76 [==============================] - 3s 38ms/step - loss: 0.4970 - accuracy: 0.8372 - val_loss: 0.5227 - val_accuracy: 0.8543
# Epoch 69/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.4777 - accuracy: 0.8461 - val_loss: 0.6134 - val_accuracy: 0.8123
# Epoch 70/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.5164 - accuracy: 0.8266 - val_loss: 0.5593 - val_accuracy: 0.8300
# Epoch 71/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.5898 - accuracy: 0.8062 - val_loss: 0.8567 - val_accuracy: 0.7111
# Epoch 72/200
# 76/76 [==============================] - 3s 35ms/step - loss: 0.5151 - accuracy: 0.8339 - val_loss: 0.5039 - val_accuracy: 0.8564
# Epoch 73/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.4819 - accuracy: 0.8453 - val_loss: 0.5307 - val_accuracy: 0.8527
# Epoch 74/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.4490 - accuracy: 0.8548 - val_loss: 0.4928 - val_accuracy: 0.8449
# Epoch 75/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.4224 - accuracy: 0.8633 - val_loss: 0.4972 - val_accuracy: 0.8383
# Epoch 76/200
# 76/76 [==============================] - 3s 35ms/step - loss: 0.4459 - accuracy: 0.8600 - val_loss: 0.5276 - val_accuracy: 0.8325
# Epoch 77/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.4468 - accuracy: 0.8593 - val_loss: 0.5323 - val_accuracy: 0.8259
# Epoch 78/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.4829 - accuracy: 0.8452 - val_loss: 0.5206 - val_accuracy: 0.8420
# Epoch 79/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.4466 - accuracy: 0.8591 - val_loss: 0.4842 - val_accuracy: 0.8588
# Epoch 80/200
# 76/76 [==============================] - 3s 43ms/step - loss: 0.4904 - accuracy: 0.8432 - val_loss: 0.5216 - val_accuracy: 0.8556
# Epoch 81/200
# 76/76 [==============================] - 2s 33ms/step - loss: 0.4745 - accuracy: 0.8508 - val_loss: 0.8966 - val_accuracy: 0.6428
# Epoch 82/200
# 76/76 [==============================] - 2s 33ms/step - loss: 0.5058 - accuracy: 0.8389 - val_loss: 0.5283 - val_accuracy: 0.8383
# Epoch 83/200
# 76/76 [==============================] - 2s 33ms/step - loss: 0.4420 - accuracy: 0.8566 - val_loss: 0.5013 - val_accuracy: 0.8469
# Epoch 84/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.4308 - accuracy: 0.8622 - val_loss: 0.4810 - val_accuracy: 0.8588
# Epoch 85/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.4058 - accuracy: 0.8694 - val_loss: 0.4590 - val_accuracy: 0.8642
# Epoch 86/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.4090 - accuracy: 0.8686 - val_loss: 0.4825 - val_accuracy: 0.8325
# Epoch 87/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.4332 - accuracy: 0.8624 - val_loss: 0.5100 - val_accuracy: 0.8630
# Epoch 88/200
# 76/76 [==============================] - 2s 33ms/step - loss: 0.4366 - accuracy: 0.8590 - val_loss: 0.5127 - val_accuracy: 0.8420
# Epoch 89/200
# 76/76 [==============================] - 3s 35ms/step - loss: 0.5013 - accuracy: 0.8419 - val_loss: 0.8011 - val_accuracy: 0.7667
# Epoch 90/200
# 76/76 [==============================] - 2s 33ms/step - loss: 0.8244 - accuracy: 0.7375 - val_loss: 0.7391 - val_accuracy: 0.7539
# Epoch 91/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.6705 - accuracy: 0.7970 - val_loss: 0.7428 - val_accuracy: 0.7416
# Epoch 92/200
# 76/76 [==============================] - 3s 38ms/step - loss: 0.5144 - accuracy: 0.8358 - val_loss: 0.5929 - val_accuracy: 0.8140
# Epoch 93/200
# 76/76 [==============================] - 3s 37ms/step - loss: 0.4987 - accuracy: 0.8389 - val_loss: 0.6133 - val_accuracy: 0.7823
# Epoch 94/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.5133 - accuracy: 0.8322 - val_loss: 0.5264 - val_accuracy: 0.8440
# Epoch 95/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.4987 - accuracy: 0.8406 - val_loss: 0.5634 - val_accuracy: 0.8284
# Epoch 96/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.5055 - accuracy: 0.8365 - val_loss: 0.6032 - val_accuracy: 0.8292
# Epoch 97/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.4785 - accuracy: 0.8446 - val_loss: 0.5684 - val_accuracy: 0.8305
# Epoch 98/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.4863 - accuracy: 0.8444 - val_loss: 0.5417 - val_accuracy: 0.8333
# Epoch 99/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.4879 - accuracy: 0.8424 - val_loss: 0.5506 - val_accuracy: 0.8391
# Epoch 100/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.5021 - accuracy: 0.8374 - val_loss: 0.5184 - val_accuracy: 0.8514
# Epoch 101/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.4488 - accuracy: 0.8588 - val_loss: 0.5197 - val_accuracy: 0.8481
# Epoch 102/200
# 76/76 [==============================] - 3s 35ms/step - loss: 0.4690 - accuracy: 0.8495 - val_loss: 0.5399 - val_accuracy: 0.8432
# Epoch 103/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.5151 - accuracy: 0.8319 - val_loss: 0.5298 - val_accuracy: 0.8272
# Epoch 104/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.4624 - accuracy: 0.8510 - val_loss: 0.4905 - val_accuracy: 0.8490
# Epoch 105/200
# 76/76 [==============================] - 3s 40ms/step - loss: 0.4600 - accuracy: 0.8483 - val_loss: 0.5302 - val_accuracy: 0.8333
# Epoch 106/200
# 76/76 [==============================] - 3s 36ms/step - loss: 0.4654 - accuracy: 0.8501 - val_loss: 0.5116 - val_accuracy: 0.8519
# Epoch 107/200
# 76/76 [==============================] - 2s 33ms/step - loss: 0.4845 - accuracy: 0.8443 - val_loss: 0.6019 - val_accuracy: 0.8115
# Epoch 108/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.4846 - accuracy: 0.8452 - val_loss: 0.5031 - val_accuracy: 0.8481
# Epoch 109/200
# 76/76 [==============================] - 2s 33ms/step - loss: 0.4409 - accuracy: 0.8564 - val_loss: 0.5422 - val_accuracy: 0.8321
# Epoch 110/200
# 76/76 [==============================] - 3s 35ms/step - loss: 0.4549 - accuracy: 0.8536 - val_loss: 0.5487 - val_accuracy: 0.8486
# Epoch 111/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.4112 - accuracy: 0.8661 - val_loss: 0.4760 - val_accuracy: 0.8531
# Epoch 112/200
# 76/76 [==============================] - 2s 33ms/step - loss: 0.4299 - accuracy: 0.8628 - val_loss: 0.5215 - val_accuracy: 0.8519
# Epoch 113/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.4740 - accuracy: 0.8476 - val_loss: 0.6316 - val_accuracy: 0.8058
# Epoch 114/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.4582 - accuracy: 0.8501 - val_loss: 0.5066 - val_accuracy: 0.8457
# Epoch 115/200
# 76/76 [==============================] - 3s 35ms/step - loss: 0.4456 - accuracy: 0.8550 - val_loss: 0.5105 - val_accuracy: 0.8461
# Epoch 116/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.4509 - accuracy: 0.8580 - val_loss: 0.5106 - val_accuracy: 0.8366
# Epoch 117/200
# 76/76 [==============================] - 3s 38ms/step - loss: 0.4435 - accuracy: 0.8523 - val_loss: 0.5312 - val_accuracy: 0.8428
# Epoch 118/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.4347 - accuracy: 0.8612 - val_loss: 0.6692 - val_accuracy: 0.8016
# Epoch 119/200
# 76/76 [==============================] - 3s 36ms/step - loss: 0.4412 - accuracy: 0.8549 - val_loss: 0.4692 - val_accuracy: 0.8580
# Epoch 120/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.4225 - accuracy: 0.8608 - val_loss: 0.6527 - val_accuracy: 0.8021
# Epoch 121/200
# 76/76 [==============================] - 2s 33ms/step - loss: 0.4553 - accuracy: 0.8497 - val_loss: 0.4860 - val_accuracy: 0.8449
# Epoch 122/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.4079 - accuracy: 0.8690 - val_loss: 0.4840 - val_accuracy: 0.8613
# Epoch 123/200
# 76/76 [==============================] - 3s 35ms/step - loss: 0.4403 - accuracy: 0.8584 - val_loss: 0.4780 - val_accuracy: 0.8584
# Epoch 124/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.4201 - accuracy: 0.8599 - val_loss: 0.4580 - val_accuracy: 0.8630
# Epoch 125/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.4204 - accuracy: 0.8622 - val_loss: 0.5332 - val_accuracy: 0.8420
# Epoch 126/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.4309 - accuracy: 0.8638 - val_loss: 0.5563 - val_accuracy: 0.8313
# Epoch 127/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.4712 - accuracy: 0.8532 - val_loss: 0.5314 - val_accuracy: 0.8230
# Epoch 128/200
# 76/76 [==============================] - 3s 36ms/step - loss: 0.4342 - accuracy: 0.8592 - val_loss: 0.6198 - val_accuracy: 0.8099
# Epoch 129/200
# 76/76 [==============================] - 3s 38ms/step - loss: 0.4599 - accuracy: 0.8543 - val_loss: 0.4643 - val_accuracy: 0.8733
# Epoch 130/200
# 76/76 [==============================] - 2s 33ms/step - loss: 0.4436 - accuracy: 0.8567 - val_loss: 0.4707 - val_accuracy: 0.8576
# Epoch 131/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.3914 - accuracy: 0.8729 - val_loss: 0.4748 - val_accuracy: 0.8617
# Epoch 132/200
# 76/76 [==============================] - 3s 36ms/step - loss: 0.4567 - accuracy: 0.8534 - val_loss: 0.5290 - val_accuracy: 0.8379
# Epoch 133/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.4615 - accuracy: 0.8494 - val_loss: 0.5148 - val_accuracy: 0.8494
# Epoch 134/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.3969 - accuracy: 0.8746 - val_loss: 0.4571 - val_accuracy: 0.8667
# Epoch 135/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.4239 - accuracy: 0.8601 - val_loss: 0.5333 - val_accuracy: 0.8477
# Epoch 136/200
# 76/76 [==============================] - 3s 35ms/step - loss: 0.4254 - accuracy: 0.8639 - val_loss: 0.4842 - val_accuracy: 0.8506
# Epoch 137/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.4410 - accuracy: 0.8563 - val_loss: 0.6395 - val_accuracy: 0.8107
# Epoch 138/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.4653 - accuracy: 0.8538 - val_loss: 0.5138 - val_accuracy: 0.8436
# Epoch 139/200
# 76/76 [==============================] - 2s 33ms/step - loss: 0.4178 - accuracy: 0.8672 - val_loss: 0.4862 - val_accuracy: 0.8531
# Epoch 140/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.3901 - accuracy: 0.8754 - val_loss: 0.5570 - val_accuracy: 0.8247
# Epoch 141/200
# 76/76 [==============================] - 3s 35ms/step - loss: 0.4179 - accuracy: 0.8615 - val_loss: 0.4889 - val_accuracy: 0.8597
# Epoch 142/200
# 76/76 [==============================] - 3s 38ms/step - loss: 0.4218 - accuracy: 0.8634 - val_loss: 0.4824 - val_accuracy: 0.8531
# Epoch 143/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.3981 - accuracy: 0.8695 - val_loss: 0.5671 - val_accuracy: 0.8165
# Epoch 144/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.4068 - accuracy: 0.8676 - val_loss: 0.4742 - val_accuracy: 0.8667
# Epoch 145/200
# 76/76 [==============================] - 3s 36ms/step - loss: 0.3770 - accuracy: 0.8776 - val_loss: 0.5241 - val_accuracy: 0.8399
# Epoch 146/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.4112 - accuracy: 0.8663 - val_loss: 0.5108 - val_accuracy: 0.8420
# Epoch 147/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.4597 - accuracy: 0.8567 - val_loss: 0.6505 - val_accuracy: 0.8222
# Epoch 148/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.4246 - accuracy: 0.8709 - val_loss: 0.5426 - val_accuracy: 0.8453
# Epoch 149/200
# 76/76 [==============================] - 3s 35ms/step - loss: 0.4365 - accuracy: 0.8615 - val_loss: 0.4536 - val_accuracy: 0.8679
# Epoch 150/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.3960 - accuracy: 0.8722 - val_loss: 0.4959 - val_accuracy: 0.8519
# Epoch 151/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.3649 - accuracy: 0.8868 - val_loss: 0.5234 - val_accuracy: 0.8453
# Epoch 152/200
# 76/76 [==============================] - 2s 33ms/step - loss: 0.3960 - accuracy: 0.8733 - val_loss: 0.5082 - val_accuracy: 0.8510
# Epoch 153/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.3840 - accuracy: 0.8727 - val_loss: 0.5086 - val_accuracy: 0.8432
# Epoch 154/200
# 76/76 [==============================] - 3s 42ms/step - loss: 0.4039 - accuracy: 0.8694 - val_loss: 0.5326 - val_accuracy: 0.8309
# Epoch 155/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.4164 - accuracy: 0.8632 - val_loss: 0.4872 - val_accuracy: 0.8580
# Epoch 156/200
# 76/76 [==============================] - 2s 33ms/step - loss: 0.3804 - accuracy: 0.8794 - val_loss: 0.5109 - val_accuracy: 0.8543
# Epoch 157/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.3787 - accuracy: 0.8757 - val_loss: 0.4977 - val_accuracy: 0.8597
# Epoch 158/200
# 76/76 [==============================] - 3s 36ms/step - loss: 0.3969 - accuracy: 0.8724 - val_loss: 0.6671 - val_accuracy: 0.8016
# Epoch 159/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.4024 - accuracy: 0.8701 - val_loss: 0.5885 - val_accuracy: 0.8305
# Epoch 160/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.3989 - accuracy: 0.8714 - val_loss: 0.4899 - val_accuracy: 0.8543
# Epoch 161/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.3750 - accuracy: 0.8797 - val_loss: 0.4687 - val_accuracy: 0.8638
# Epoch 162/200
# 76/76 [==============================] - 3s 35ms/step - loss: 0.4157 - accuracy: 0.8668 - val_loss: 0.5089 - val_accuracy: 0.8440
# Epoch 163/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.3682 - accuracy: 0.8827 - val_loss: 0.4749 - val_accuracy: 0.8712
# Epoch 164/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.3770 - accuracy: 0.8808 - val_loss: 0.5797 - val_accuracy: 0.8226
# Epoch 165/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.4083 - accuracy: 0.8677 - val_loss: 0.4985 - val_accuracy: 0.8597
# Epoch 166/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.4587 - accuracy: 0.8505 - val_loss: 0.5488 - val_accuracy: 0.8432
# Epoch 167/200
# 76/76 [==============================] - 3s 42ms/step - loss: 0.3942 - accuracy: 0.8756 - val_loss: 0.4909 - val_accuracy: 0.8551
# Epoch 168/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.4095 - accuracy: 0.8695 - val_loss: 0.4672 - val_accuracy: 0.8638
# Epoch 169/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.3666 - accuracy: 0.8822 - val_loss: 0.5067 - val_accuracy: 0.8593
# Epoch 170/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.3696 - accuracy: 0.8832 - val_loss: 0.5025 - val_accuracy: 0.8646
# Epoch 171/200
# 76/76 [==============================] - 3s 35ms/step - loss: 0.3656 - accuracy: 0.8815 - val_loss: 0.5031 - val_accuracy: 0.8597
# Epoch 172/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.3668 - accuracy: 0.8828 - val_loss: 0.4993 - val_accuracy: 0.8477
# Epoch 173/200
# 76/76 [==============================] - 2s 33ms/step - loss: 0.3631 - accuracy: 0.8830 - val_loss: 0.4807 - val_accuracy: 0.8621
# Epoch 174/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.3927 - accuracy: 0.8712 - val_loss: 0.5526 - val_accuracy: 0.8370
# Epoch 175/200
# 76/76 [==============================] - 3s 35ms/step - loss: 0.4006 - accuracy: 0.8711 - val_loss: 0.4929 - val_accuracy: 0.8556
# Epoch 176/200
# 76/76 [==============================] - 2s 33ms/step - loss: 0.3602 - accuracy: 0.8828 - val_loss: 0.4751 - val_accuracy: 0.8609
# Epoch 177/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.3398 - accuracy: 0.8928 - val_loss: 0.4752 - val_accuracy: 0.8630
# Epoch 178/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.3222 - accuracy: 0.9006 - val_loss: 0.4748 - val_accuracy: 0.8683
# Epoch 179/200
# 76/76 [==============================] - 3s 39ms/step - loss: 0.3443 - accuracy: 0.8880 - val_loss: 0.5135 - val_accuracy: 0.8556
# Epoch 180/200
# 76/76 [==============================] - 3s 35ms/step - loss: 0.3590 - accuracy: 0.8847 - val_loss: 0.5049 - val_accuracy: 0.8551
# Epoch 181/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.3677 - accuracy: 0.8849 - val_loss: 0.4518 - val_accuracy: 0.8626
# Epoch 182/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.3274 - accuracy: 0.8932 - val_loss: 0.4388 - val_accuracy: 0.8683
# Epoch 183/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.3708 - accuracy: 0.8811 - val_loss: 0.5087 - val_accuracy: 0.8391
# Epoch 184/200
# 76/76 [==============================] - 3s 35ms/step - loss: 0.4022 - accuracy: 0.8697 - val_loss: 0.5567 - val_accuracy: 0.8346
# Epoch 185/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.3728 - accuracy: 0.8812 - val_loss: 0.4846 - val_accuracy: 0.8588
# Epoch 186/200
# 76/76 [==============================] - 2s 33ms/step - loss: 0.3310 - accuracy: 0.8925 - val_loss: 0.4746 - val_accuracy: 0.8424
# Epoch 187/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.3453 - accuracy: 0.8883 - val_loss: 0.4484 - val_accuracy: 0.8667
# Epoch 188/200
# 76/76 [==============================] - 3s 35ms/step - loss: 0.3476 - accuracy: 0.8863 - val_loss: 0.4621 - val_accuracy: 0.8613
# Epoch 189/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.3709 - accuracy: 0.8814 - val_loss: 0.4610 - val_accuracy: 0.8667
# Epoch 190/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.3483 - accuracy: 0.8940 - val_loss: 0.4581 - val_accuracy: 0.8626
# Epoch 191/200
# 76/76 [==============================] - 3s 36ms/step - loss: 0.3330 - accuracy: 0.8919 - val_loss: 0.5113 - val_accuracy: 0.8564
# Epoch 192/200
# 76/76 [==============================] - 3s 35ms/step - loss: 0.3572 - accuracy: 0.8840 - val_loss: 0.5071 - val_accuracy: 0.8506
# Epoch 193/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.4174 - accuracy: 0.8627 - val_loss: 0.5058 - val_accuracy: 0.8617
# Epoch 194/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.4221 - accuracy: 0.8656 - val_loss: 0.6053 - val_accuracy: 0.8177
# Epoch 195/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.3748 - accuracy: 0.8787 - val_loss: 0.4792 - val_accuracy: 0.8646
# Epoch 196/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.3430 - accuracy: 0.8862 - val_loss: 0.4376 - val_accuracy: 0.8691
# Epoch 197/200
# 76/76 [==============================] - 3s 35ms/step - loss: 0.3312 - accuracy: 0.8919 - val_loss: 0.5052 - val_accuracy: 0.8502
# Epoch 198/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.3181 - accuracy: 0.8967 - val_loss: 0.4247 - val_accuracy: 0.8778
# Epoch 199/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.3266 - accuracy: 0.8944 - val_loss: 0.4820 - val_accuracy: 0.8663
# Epoch 200/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.3427 - accuracy: 0.8862 - val_loss: 0.4556 - val_accuracy: 0.8593
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 500, 22)]         0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 500, 128)          8576
# _________________________________________________________________
# lstm (LSTM)                  (None, 500, 64)           49408
# _________________________________________________________________
# flatten (Flatten)            (None, 32000)             0
# _________________________________________________________________
# dense (Dense)                (None, 8)                 256008
# =================================================================
# Total params: 313,992
# Trainable params: 313,992
# Non-trainable params: 0
# _________________________________________________________________
# None
# Confusion matrix, without normalization
# [[309   2   0   0   0  10  21  30]
#  [  2 301   1   0   2   0   9   0]
#  [  7   0 279   1   6   3   5   2]
#  [  0   0   0  42   0   0   1   0]
#  [  7   3   1   0 197   0   0   0]
#  [  3   1   0   0   0 408   9   6]
#  [ 67  22   6   0   0  29 287   2]
#  [ 50   5   1   0   0  16  12 265]]
